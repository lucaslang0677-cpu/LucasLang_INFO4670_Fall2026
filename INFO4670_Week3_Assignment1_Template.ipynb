# %% [markdown]
# <a href="https://colab.research.google.com/github/lucaslang0677-cpu/LucasLang_INFO4670_Fall2026/blob/main/INFO4670_Week3_Assignment1_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 — Making Sense of Northgate through Visualization
# **INFO 4670 · Data Analysis and Knowledge Discovery**  ·  **Due: Sunday, 11:59 PM**
#
# **Name:** Lucas Lang    **Date:** 9/6/2026
#
# **The situation.** The Provost's question stands: *which students are struggling, and can we see it earlier?* This week you answer it the way analysts do — not by reading rows, but by drawing the data. Every chart below is built by **adapting code from the Guided notebook**; the intellectual work is choosing the right chart and reading it honestly.
#
# **For every chart you make, you must:**
# 1. **Choose** the chart type that fits the variable(s) and the question.
# 2. **Build** it in Colab from the Northgate files.
# 3. **Label** it fully — title, axis labels, and units/legend. *An unlabeled chart is an unfinished chart.*
# 4. **Write a STAR story** underneath it — Scope · Track · Articulate · Respond (defined on the Concepts deck).
#
# **How to work:** run Setup and Load first. Then, for each question, copy the closest cell from the Guided notebook into the empty cell, adapt it, and fill in the STAR cell below it.
#
# **Submit:** push this notebook to GitHub and submit the **GitHub link** in Canvas. (See the setup doc: *Colab_GitHub_Setup_INFO4670_Fall2026*.)

# %% [markdown]
# ## Setup — run this first (you don't need to change it)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Northgate house style (optional, but keeps your charts consistent)
NAVY = "#22303A"
RUST = "#C0562F"
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"]   = (8, 5)
plt.rcParams["axes.titlesize"]   = 13
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# ## Load the data — run this, then look before you plot

# %%
# STEP 1 — get the data into this notebook. Pick ONE option, then run.

DATA_DIR = "."   # OPTION 2 (default) · drag the 3 CSVs into the file panel on the left

# OPTION 1 · read from Google Drive — uncomment and edit the path:
# from google.colab import drive
# drive.mount("/content/drive")
# DATA_DIR = "/content/drive/MyDrive/.../Data"

import os
students = pd.read_csv(os.path.join(DATA_DIR, "student_records.csv"))
weekly = pd.read_csv(os.path.join(DATA_DIR, "weekly_activity.csv"))
students.head()
# Out:
#   student_id                   major  age      housing  commute_miles  \
# 0  NU-101508            Data Science   27   Off-Campus            7.6
# 1  NU-102438   Learning Technologies   25  With Family           14.3
# 2  NU-102385   Learning Technologies   26  With Family            3.4
# 3  NU-100767          Cyber Security   22    On-Campus           23.7
# 4  NU-106054  Information Technology   21   Off-Campus            2.3
#
#    work_hours_per_week  advisor_meetings  credits_attempted  final_gpa  \
# 0                   15                 1                 81       1.86
# 1                   35                 1                100       2.06
# 2                   18                 9                 77       3.41
# 3                   40                 1                 65       1.73
# 4                   20                 4                 59       2.37
#
#    study_hours_reported enrollment_date  dropped_out
# 0                   NaN      2023-09-13            1
# ...

# %%
# how many rows, which columns, what types?
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027 entries, 0 to 2026
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            2027 non-null   object
#  1   major                 2027 non-null   object
#  2   age                   2027 non-null   int64
#  3   housing               2027 non-null   object
#  4   commute_miles         2027 non-null   float64
#  5   work_hours_per_week   2027 non-null   int64
#  6   advisor_meetings      2027 non-null   int64
#  7   credits_attempted     2027 non-null   int64
#  8   final_gpa             2027 non-null   float64
#  9   study_hours_reported  1772 non-null   float64
#  10  enrollment_date       2027 non-null   object
#  11  dropped_out           2027 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 190.2+ KB

# %% [markdown]
# # Part A — Guided questions
# Build **one chart per question**. Each maps to one chart family from this week. Copy the closest Guided-notebook cell, adapt it, label it, then write its STAR story.

# %% [markdown]
# ### Q1 · One quantitative variable
# **How many hours per week do Northgate students work?** Describe what's typical, how spread out it is, and whether anyone stands apart.
# → *histogram* (add a *box plot* if it helps). Column: `work_hours_per_week` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.histplot(
    data=students,
    x="work_hours_per_week",
    color=NAVY,
    ax=ax
)

ax.set_title("Weekly Work Hours of Northgate Students")
ax.set_xlabel("Work Hours per Week")
ax.set_ylabel("Number of Students")

plt.show()

# %% [markdown]
# **STAR story — Q1** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students) The chart compares a sample of students to the amount of hours they work per week.
# - **Track —** which question are you answering? How many hours per week do Northgate students work?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend) Most of the students work about 10 to 20 hours per week. As it goes from 20 to 30 to 40, the amount of students decline. The is also a higher spike of students at the hours incrementing in 10 (0,10,20,30).
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)* This seems pretty typical for college students. Most students have the time to work about 20 hours a week and balance school at the same time. Most would agree that more than 40 hours of work a week would affect a students education.

# %% [markdown]
# ### Q2 · One categorical variable
# **How does enrollment compare across majors?**
# → *sorted bar chart*. Column: `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

major_counts = students["major"].value_counts().sort_values()

fig, ax = plt.subplots()

major_counts.plot.barh(ax=ax, color=NAVY)

ax.set_title("Enrollment Across Majors")
ax.set_xlabel("Number of Students")
ax.set_ylabel("Major")

plt.show()

# %% [markdown]
# **STAR story — Q2** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students) It compares a sample of students to which major they are currently enrolled in.
# - **Track —** which question are you answering? How does enrollment compare across majors?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend) The major with the most amount of students enrolled is Cybersecurity followed by information science, data science, information technology, business analytics, and so on.
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)* Cybersecurity isn't the major I would expect to have the most students enrolled. I thought that Information technology or Business Analytics would have the most.

# %% [markdown]
# ### Q3 · A quantity, split by category
# **Does final GPA differ across majors?** Read the exceptions, not just the boxes.
# → *box plot per major*. Columns: `final_gpa` and `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.boxplot(
    data=students,
    x="major",
    y="final_gpa",
    ax=ax
)

ax.set_title("Final GPA Across Majors")
ax.set_xlabel("Major")
ax.set_ylabel("Final GPA")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **STAR story — Q3** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students) It shows the final GPA of students across different majors.
# - **Track —** which question are you answering? Does final GPA differ across majors?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend) The spread is actually pretty compact,some ranges vary differently, but all of the average GPA's are between 2.0 and 2.5 for every major.
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)* This seems pretty expected to me, while some majors can be harder than others, there is enough students in each major to produce a similar average.

# %% [markdown]
# ### Q4 · Two quantitative variables
# **Is there a relationship between how far students commute and their final GPA?** Remember: *association is not causation.*
# → *scatterplot with a trend line*. Columns: `commute_miles` and `final_gpa` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.regplot(
    data=students,
    x="commute_miles",
    y="final_gpa",
    ax=ax
)

ax.set_title("Commute Distance and Final GPA")
ax.set_xlabel("Commute Distance (miles)")
ax.set_ylabel("Final GPA")

plt.show()

# %% [markdown]
# **STAR story — Q4** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students) It compares students final GPA's to the distance they have to commute to school.
# - **Track —** which question are you answering? Is there a relationship between how far students commute and their final GPA?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend) It shows that typically the students that don't have to commute as far have a higher GPA. The sample size is also bigger for students that don't commute as far, and the sameple size shrinks as the commute distance increases.
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)* I feel like this is to be expected. students that don't have to commute as far, can spend more time on schoolwork and have an easier time making it to class on time.

# %% [markdown]
# ### Q5 · Over time
# **How does student engagement change across the semester?**
# → *line chart* of average weekly activity. Use the `weekly` table: `week` and `minutes_active` (you'll need to average by week first — see the Guided notebook).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

weekly_avg = (
    weekly
    .groupby("week", as_index=False)["minutes_active"]
    .mean()
)

fig, ax = plt.subplots()

sns.lineplot(
    data=weekly_avg,
    x="week",
    y="minutes_active",
    marker="o",
    ax=ax
)

ax.set_title("Average Student Engagement Across the Semester")
ax.set_xlabel("Week")
ax.set_ylabel("Average Minutes Active")

plt.show()

# %% [markdown]
# **STAR story — Q5** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students) It compares the average minutes students are actively engage to to each week in the semester.
# - **Track —** which question are you answering? How does student engagement change across the semester?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend) It shows that students stay highly engaged for every week of the semester except between week 8 and 10, specifically week 9. There is a steep drop of of the minutes students are actively engaged around the middle of the semester.
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)* It was expected that there would be a drop off of engagement towards the middle of the semester, but I am surprised that students stay highly engaged for every other week besides those 2 weeks.

# %% [markdown]
# # Part B — Your own question (open)
# Pose **one question of your own** about the Northgate students, choose the chart that answers it, build it, label it, and write its STAR story. Going beyond Part A is rewarded — a per-student line chart, a violin plot, or a chart of a messier column are all fair game.
#
# **Your question:** \_\_\_\_\_\_\_\_

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.regplot(
    data=students,
    x="work_hours_per_week",
    y="final_gpa",
    ax=ax
)

ax.set_title("Work Hours per Week and Final GPA")
ax.set_xlabel("Work Hours per Week")
ax.set_ylabel("Final GPA")

plt.show()

# %% [markdown]
# **STAR story — Part B** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students) Students final GPA's being compared to the amount of hours the work per week.
# - **Track —** which question are you answering? How does final GPA vary depending on the number of hours students work per week?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend) The trend is that the average final GPA's of students will gradully decrease the more hours a week they work.
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)* This seems expected as working takes away time from studying and schoolwork which can lower GPA. however, there are some outliers which is also expected as working some hours a week can help productivity in some cases.

# %% [markdown]
# # Before you submit — checklist
# - [ ] The notebook **runs top to bottom** with no errors (Runtime → Restart and run all).
# - [ ] All **6 charts** are present, each with a title, labeled axes, and units/legend where needed.
# - [ ] Each chart has a **complete STAR story**, including any exceptions you spotted.
# - [ ] Part B question is written in and answered.
# - [ ] Pushed to **GitHub**, and the **GitHub link** is submitted in Canvas.
#
# **Rubric (70 pts):** chart choice 10 · correct build 20 · labeling 10 · STAR reading 18 · Part B question 4 · submission & professionalism 8.
